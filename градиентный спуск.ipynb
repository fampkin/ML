# %%
import numpy as np

# %%
class GradientDescent:
    def __init__(self, func, grad_func, learning_rate=0.01, max_iters=1000):
        self.func = func
        self.grad_func = grad_func
        self.learning_rate = learning_rate
        self.max_iters = max_iters

    def step(self, params, show_step=False):
        new_params = params - self.learning_rate * self.grad_func(params)
        if show_step:
            self.show_step_results(new_params)
        return new_params

    def minimize(self, init_params, delta=None, show_steps=False):
        old_params = init_params
        for _ in range(self.max_iters):
            new_params = self.step(old_params, show_step=show_steps)
            if delta is not None and np.abs(self.func(new_params) - self.func(old_params)) < delta:
                break
            old_params = new_params
        return new_params

    def show_step_results(self, params):
        print(f"Значение параметров: {params}")
        print(f"Значение функции: {self.func(params)}")

# %%
def func(params):
    x, y = params
    return x**2 + y**2

def grad_func(params):
    x, y = params
    return np.array([2*x, 2*y])

# %%
gd = GradientDescent(func, grad_func, learning_rate=0.1, max_iters=100)
gd.minimize(np.array([5.0, 5.0]), show_steps=True)
# Out:
# Значение параметров: [4. 4.]
# Значение функции: 32.0
# Значение параметров: [3.2 3.2]
# Значение функции: 20.480000000000004
# Значение параметров: [2.56 2.56]
# Значение функции: 13.1072
# Значение параметров: [2.048 2.048]
# Значение функции: 8.388608
# Значение параметров: [1.6384 1.6384]
# Значение функции: 5.36870912
# Значение параметров: [1.31072 1.31072]
# Значение функции: 3.4359738368000006
# Значение параметров: [1.048576 1.048576]
# Значение функции: 2.199023255552001
# Значение параметров: [0.8388608 0.8388608]
# Значение функции: 1.4073748835532807
# Значение параметров: [0.67108864 0.67108864]
# Значение функции: 0.9007199254740995
# Значение параметров: [0.53687091 0.53687091]
# Значение функции: 0.5764607523034238
# Значение параметров: [0.42949673 0.42949673]
# Значение функции: 0.36893488147419123
# Значение параметров: [0.34359738 0.34359738]
# Значение функции: 0.23611832414348238
# Значение параметров: [0.27487791 0.27487791]
# Значение функции: 0.1511157274518287
# Значение параметров: [0.21990233 0.21990233]
# Значение функции: 0.09671406556917037
# Значение параметров: [0.17592186 0.17592186]
# Значение функции: 0.06189700196426903
# Значение параметров: [0.14073749 0.14073749]
# Значение функции: 0.03961408125713217
# Значение параметров: [0.11258999 0.11258999]
# Значение функции: 0.025353012004564593
# Значение параметров: [0.09007199 0.09007199]
# Значение функции: 0.01622592768292134
# Значение параметров: [0.07205759 0.07205759]
# Значение функции: 0.010384593717069656
# Значение параметров: [0.05764608 0.05764608]
# Значение функции: 0.006646139978924581
# Значение параметров: [0.04611686 0.04611686]
# Значение функции: 0.004253529586511731
# Значение параметров: [0.03689349 0.03689349]
# Значение функции: 0.0027222589353675082
# Значение параметров: [0.02951479 0.02951479]
# Значение функции: 0.001742245718635205
# Значение параметров: [0.02361183 0.02361183]
# Значение функции: 0.0011150372599265314
# Значение параметров: [0.01888947 0.01888947]
# Значение функции: 0.0007136238463529801
# Значение параметров: [0.01511157 0.01511157]
# Значение функции: 0.00045671926166590733
# Значение параметров: [0.01208926 0.01208926]
# Значение функции: 0.0002923003274661807
# Значение параметров: [0.00967141 0.00967141]
# Значение функции: 0.00018707220957835566
# Значение параметров: [0.00773713 0.00773713]
# Значение функции: 0.00011972621413014761
# Значение параметров: [0.0061897 0.0061897]
# Значение функции: 7.662477704329447e-05
# Значение параметров: [0.00495176 0.00495176]
# Значение функции: 4.903985730770847e-05
# Значение параметров: [0.00396141 0.00396141]
# Значение функции: 3.1385508676933425e-05
# Значение параметров: [0.00316913 0.00316913]
# Значение функции: 2.008672555323739e-05
# Значение параметров: [0.0025353 0.0025353]
# Значение функции: 1.2855504354071932e-05
# Значение параметров: [0.00202824 0.00202824]
# Значение функции: 8.227522786606036e-06
# Значение параметров: [0.00162259 0.00162259]
# Значение функции: 5.2656145834278635e-06
# Значение параметров: [0.00129807 0.00129807]
# Значение функции: 3.369993333393833e-06
# Значение параметров: [0.00103846 0.00103846]
# Значение функции: 2.156795733372053e-06
# Значение параметров: [0.00083077 0.00083077]
# Значение функции: 1.3803492693581141e-06
# Значение параметров: [0.00066461 0.00066461]
# Значение функции: 8.834235323891929e-07
# Значение параметров: [0.00053169 0.00053169]
# Значение функции: 5.653910607290834e-07
# Значение параметров: [0.00042535 0.00042535]
# Значение функции: 3.618502788666134e-07
# Значение параметров: [0.00034028 0.00034028]
# Значение функции: 2.3158417847463256e-07
# Значение параметров: [0.00027223 0.00027223]
# Значение функции: 1.4821387422376482e-07
# Значение параметров: [0.00021778 0.00021778]
# Значение функции: 9.485687950320949e-08
# Значение параметров: [0.00017422 0.00017422]
# Значение функции: 6.070840288205407e-08
# Значение параметров: [0.00013938 0.00013938]
# Значение функции: 3.88533778445146e-08
# Значение параметров: [0.0001115 0.0001115]
# Значение функции: 2.4866161820489344e-08
# Значение параметров: [8.92029808e-05 8.92029808e-05]
# Значение функции: 1.591434356511318e-08
# Значение параметров: [7.13623846e-05 7.13623846e-05]
# Значение функции: 1.0185179881672436e-08
# Значение параметров: [5.70899077e-05 5.70899077e-05]
# Значение функции: 6.5185151242703606e-09
# Значение параметров: [4.56719262e-05 4.56719262e-05]
# Значение функции: 4.17184967953303e-09
# Значение параметров: [3.65375409e-05 3.65375409e-05]
# Значение функции: 2.6699837949011395e-09
# Значение параметров: [2.92300327e-05 2.92300327e-05]
# Значение функции: 1.7087896287367294e-09
# Значение параметров: [2.33840262e-05 2.33840262e-05]
# Значение функции: 1.0936253623915066e-09
# Значение параметров: [1.8707221e-05 1.8707221e-05]
# Значение функции: 6.999202319305643e-10
# Значение параметров: [1.49657768e-05 1.49657768e-05]
# Значение функции: 4.479489484355612e-10
# Значение параметров: [1.19726214e-05 1.19726214e-05]
# Значение функции: 2.8668732699875916e-10
# Значение параметров: [9.57809713e-06 9.57809713e-06]
# Значение функции: 1.8347988927920585e-10
# Значение параметров: [7.6624777e-06 7.6624777e-06]
# Значение функции: 1.1742712913869176e-10
# Значение параметров: [6.12998216e-06 6.12998216e-06]
# Значение функции: 7.515336264876274e-11
# Значение параметров: [4.90398573e-06 4.90398573e-06]
# Значение функции: 4.809815209520816e-11
# Значение параметров: [3.92318858e-06 3.92318858e-06]
# Значение функции: 3.078281734093322e-11
# Значение параметров: [3.13855087e-06 3.13855087e-06]
# Значение функции: 1.9701003098197258e-11
# Значение параметров: [2.51084069e-06 2.51084069e-06]
# Значение функции: 1.2608641982846245e-11
# Значение параметров: [2.00867256e-06 2.00867256e-06]
# Значение функции: 8.069530869021598e-12
# Значение параметров: [1.60693804e-06 1.60693804e-06]
# Значение функции: 5.164499756173823e-12
# Значение параметров: [1.28555044e-06 1.28555044e-06]
# Значение функции: 3.305279843951246e-12
# Значение параметров: [1.02844035e-06 1.02844035e-06]
# Значение функции: 2.1153791001287975e-12
# Значение параметров: [8.22752279e-07 8.22752279e-07]
# Значение функции: 1.3538426240824304e-12
# Значение параметров: [6.58201823e-07 6.58201823e-07]
# Значение функции: 8.664592794127554e-13
# Значение параметров: [5.26561458e-07 5.26561458e-07]
# Значение функции: 5.545339388241635e-13
# Значение параметров: [4.21249167e-07 4.21249167e-07]
# Значение функции: 3.5490172084746464e-13
# Значение параметров: [3.36999333e-07 3.36999333e-07]
# Значение функции: 2.2713710134237736e-13
# Значение параметров: [2.69599467e-07 2.69599467e-07]
# Значение функции: 1.4536774485912155e-13
# Значение параметров: [2.15679573e-07 2.15679573e-07]
# Значение функции: 9.303535670983778e-14
# Значение параметров: [1.72543659e-07 1.72543659e-07]
# Значение функции: 5.954262829429618e-14
# Значение параметров: [1.38034927e-07 1.38034927e-07]
# Значение функции: 3.810728210834955e-14
# Значение параметров: [1.10427942e-07 1.10427942e-07]
# Значение функции: 2.4388660549343712e-14
# Значение параметров: [8.83423532e-08 8.83423532e-08]
# Значение функции: 1.5608742751579975e-14
# Значение параметров: [7.06738826e-08 7.06738826e-08]
# Значение функции: 9.989595361011186e-15
# Значение параметров: [5.65391061e-08 5.65391061e-08]
# Значение функции: 6.393341031047159e-15
# Значение параметров: [4.52312849e-08 4.52312849e-08]
# Значение функции: 4.091738259870182e-15
# Значение параметров: [3.61850279e-08 3.61850279e-08]
# Значение функции: 2.6187124863169164e-15
# Значение параметров: [2.89480223e-08 2.89480223e-08]
# Значение функции: 1.6759759912428267e-15
# Значение параметров: [2.31584178e-08 2.31584178e-08]
# Значение функции: 1.072624634395409e-15
# Значение параметров: [1.85267343e-08 1.85267343e-08]
# Значение функции: 6.864797660130618e-16
# Значение параметров: [1.48213874e-08 1.48213874e-08]
# Значение функции: 4.393470502483595e-16
# Значение параметров: [1.18571099e-08 1.18571099e-08]
# Значение функции: 2.811821121589501e-16
# Значение параметров: [9.48568795e-09 9.48568795e-09]
# Значение функции: 1.7995655178172807e-16
# Значение параметров: [7.58855036e-09 7.58855036e-09]
# Значение функции: 1.1517219314030598e-16
# Значение параметров: [6.07084029e-09 6.07084029e-09]
# Значение функции: 7.371020360979583e-17
# Значение параметров: [4.85667223e-09 4.85667223e-09]
# Значение функции: 4.717453031026933e-17
# Значение параметров: [3.88533778e-09 3.88533778e-09]
# Значение функции: 3.019169939857238e-17
# Значение параметров: [3.10827023e-09 3.10827023e-09]
# Значение функции: 1.9322687615086322e-17
# Значение параметров: [2.48661618e-09 2.48661618e-09]
# Значение функции: 1.2366520073655247e-17
# Значение параметров: [1.98929295e-09 1.98929295e-09]
# Значение функции: 7.914572847139357e-18
# Значение параметров: [1.59143436e-09 1.59143436e-09]
# Значение функции: 5.065326622169188e-18
# Значение параметров: [1.27314749e-09 1.27314749e-09]
# Значение функции: 3.2418090381882805e-18
# Значение параметров: [1.01851799e-09 1.01851799e-09]
# Значение функции: 2.0747577844404998e-18
# array([1.01851799e-09, 1.01851799e-09])

# %%
gd.step(np.array([5.0, 5.0]), True)
# Out:
# Значение параметров: [4. 4.]
# Значение функции: 32.0
# array([4., 4.])

# %%
# (x - 2)^2 + (y - 3)^2 - (z - 7)^2

# %%
def func2(params):
    x, y, z = params
    return (x - 2)**2 + (y - 3)**2 + (z - 7)**2

def grad_func2(params):
    x, y, z = params
    return np.array([2 * (x - 2), 2 * (y - 3), 2 * (z - 7)])

gd2 = GradientDescent(func2, grad_func2, learning_rate=0.1, max_iters=100)
gd2.minimize(np.array([2, 2, 2]), delta=1, show_steps=True)
# Out:
# Значение параметров: [2.  2.2 3. ]
# Значение функции: 16.64
# Значение параметров: [2.   2.36 3.8 ]
# Значение функции: 10.649600000000001
# Значение параметров: [2.    2.488 4.44 ]
# Значение функции: 6.815744000000002
# Значение параметров: [2.     2.5904 4.952 ]
# Значение функции: 4.36207616
# Значение параметров: [2.      2.67232 5.3616 ]
# Значение функции: 2.7917287423999997
# Значение параметров: [2.       2.737856 5.68928 ]
# Значение функции: 1.7867063951359996
# Значение параметров: [2.        2.7902848 5.951424 ]
# Значение функции: 1.1434920928870396
# array([2.       , 2.7902848, 5.951424 ])
